# %%
using Pkg
Pkg.activate("/home/thomas/JuliaTensor/JuliaTensorPackages/AbstractTensor")
using AbstractTensors

@defManifold(M, 4, [μ, ν, ρ, σ])
@show is_manifold(M)           # true
@show tangent_bundle_of(M)    # :TangentM
tangent_bundle_of(M)
# @show indices_of_vbundle(tangent_bundle_of(M))
# Out:
#   Activating
# Defined manifold M of dimension 4 with tangent bundle TangentM and cotangent bundle CoTangentM
# project at `~/JuliaTensor/JuliaTensorPackages/AbstractTensor`
# is_manifold(M) = true
# tangent_bundle_of(M) = :TangentM
# :TangentM

# %%
@show tangent_bundle_of(M)
cotangent_bundle_of(M)
# Out:
# tangent_bundle_of(M) = :TangentM
# :CoTangentM

# %%
_MANIFOLDS[:M]
# Out:
# FieldError: type ManifoldRecord has no field `indices`, available fields: `name`, `dim`, `tangent_bundle`, `cotangent_bundle`, `vbundles`
#
#
#
# Stacktrace:
#
#   [1] getproperty
#
#     @ ./Base_compiler.jl:54 [inlined]
#
#   [2] show(io::IOContext{IOBuffer}, d::ManifoldRecord)
#
#     @ AbstractTensor ~/JuliaTensor/JuliaTensorPackages/AbstractTensor/src/manifolds.jl:386
#
#   [3] show(io::IOContext{IOBuffer}, ::MIME{Symbol("text/plain")}, x::ManifoldRecord)
#
#     @ Base.Multimedia ./multimedia.jl:47
#
#   [4] limitstringmime(mime::MIME{Symbol("text/plain")}, x::ManifoldRecord)
#
#     @ VSCodeServer.IJuliaCore ~/.cursor/extensions/julialang.language-julia-1.174.2-universal/scripts/packages/IJuliaCore/src/inline.jl:22
#
#   [5] display_mimestring(m::MIME{Symbol("text/plain")}, x::ManifoldRecord)
#
#     @ VSCodeServer.IJuliaCore ~/.cursor/extensions/julialang.language-julia-1.174.2-universal/scripts/packages/IJuliaCore/src/display.jl:67
#
#   [6] display_dict(x::ManifoldRecord)
# ...
